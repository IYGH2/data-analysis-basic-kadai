# %%
# numpyをインポート
import numpy as np

# AとBの行列を格納する多次元配列を記述
A = np.array([[0, 1], [2, 3], [4, 5]])
B = np.array([[0, 1, 2, 3], [4, 5, 6, 7]])

# 行列の積を計算・表示
C = np.dot(A, B)
C
# Out:
# array([[ 4,  5,  6,  7],
#        [12, 17, 22, 27],
#        [20, 29, 38, 47]])

# %%
# 行列の最大値を求めるコードを記述・最大値を表示
C.max()
# Out:
# 47
